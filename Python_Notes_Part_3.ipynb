# %% [markdown]
# ### <div class="alert alert-block alert-info"></b> Index</div>

# %% [markdown]
# - <span style='color:red'>Python RegEx</span>
#   - <span style='color:green'>RegEx Module</span>
#   - <span style='color:green'>RegEx in Python</span>
#   - <span style='color:green'>RegEx Functions</span>
#
#
# - <span style='color:red'>Python Try Except</span>
#   - <span style='color:green'>Exception Handling</span>
#   - <span style='color:green'>Many Exceptions</span>
#   - <span style='color:green'>Else</span>
#   - <span style='color:green'>Finally</span>
#   - <span style='color:green'>Raise an exception</span>
#   - <span style='color:green'>Some useful exceptions</span>
#
#
# - <span style='color:red'>Python logging</span>
#
#
# - <span style='color:red'>Object Oriented Programming</span>
#   - <span style='color:green'>Main Concepts of Object-Oriented Programming (OOPs)</span>
#   - <span style='color:green'>Class</span>
#   - <span style='color:green'>Objects</span>
#   - <span style='color:green'>Python Methods</span>
#   - <span style='color:green'>Python __init__</span>
#   - <span style='color:green'>Attributes</span>
#   - <span style='color:green'>Variables</span>
#   - <span style='color:green'>Types of Methods</span>
#   - <span style='color:green'>Inner Class</span>
#   - <span style='color:green'>Python Inheritance</span>

# %% [markdown]
# ## <div class="alert alert-block alert-danger"><b>Python RegEx</b> </div>

# %% [markdown]
# - A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.
#
# - RegEx can be used to check if a string contains the specified search pattern.
#
# - This will work like __'Like'__ operator in SQL.
#
# - These are supported by many languages such as python, java, R etc.Most common uses of regular expressions are:
#     - Finding patterns in a string or file.(Ex: find all the numbers present in a string)
#     - Replace a part of the string with another string.
#     - Search substring in string or file.
#     - Split string into substrings.
#     - Validate email format.
#
# We will see examples of above mentioned uses in detail.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>RegEx Module</b></div>

# %% [markdown]
# Python has a built-in package called <span style='color:red'>re</span>, which can be used to work with Regular Expressions.
#
# Import the <span style='color:red'>re</span> module:

# %%
import re

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>RegEx in Python</b></div>

# %% [markdown]
# When you have imported the <span style='color:red'>re</span> module, you can start using regular expressions:

# %% [markdown]
# __Example:__ Search the string to see if it starts with "The" and ends with "Spain":

# %%
import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

if x:
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# YES! We have a match!

# %% [markdown]
# __Example:__

# %%
import re

s = 'GeeksforGeeks: A computer science portal for geeks'

match = re.search('portal', s)

print('Start Index:', match.start())
print('End Index:', match.end())
# Out:
# Start Index: 34
# End Index: 40

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>RegEx Functions</b></div>

# %% [markdown]
# The <span style='color:red'>re</span> module offers a set of functions that allows us to search a string for a match:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### The findall() Function

# %% [markdown]
# The <span style='color:red'>findall()</span> function returns a list containing all matches.

# %% [markdown]
# __Example:__

# %%
import re

txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %% [markdown]
# - The list contains the matches in the order they are found.
#
# - If no matches are found, an empty list is returned:

# %% [markdown]
# __Example:__

# %%
import re

txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
# Out:
# []

# %% [markdown]
# ### The search() Function

# %% [markdown]
# - The <span style='color:red'>search()</span> function searches the string for a match, and returns a Match object if there is a match.
#
# - If there is more than one match, only the first occurrence of the match will be returned:

# %% [markdown]
# __Example:__

# %%
import re

txt = "The rain in Spain"
x = re.search("Spain", txt)
print(x)
# Out:
# <re.Match object; span=(12, 17), match='Spain'>
# 12
# 17

# %% [markdown]
# __Example:__

# %%
import re

txt = "The rain in Spain"
x = re.search("Spain", txt)

print("The character is located in position:", x.start()) 
print("The character is located in position:", x.end())
# Out:
# The character is located in position: 12
# The character is located in position: 17

# %% [markdown]
# __Example:__

# %%
import re

txt = "The rain in Spain"
x = re.search("Portugal", txt)
print(x)
# Out:
# None

# %% [markdown]
# If no matches are found, the value None is returned:

# %% [markdown]
# ### The split() Function

# %% [markdown]
# The <span style='color:red'>split()</span> function returns a list where the string has been split at each match:

# %%
import re

#Split the string at every white-space character:

txt = "The rain in Spain"
x = re.split(" rain in ", txt)
print(x)
# Out:
# ['The', 'Spain']

# %% [markdown]
# You can control the number of occurrences by specifying the <span style='color:red'>maxsplit</span> parameter:

# %%
import re

txt = "The rain in Spain"
x = re.split("\s", txt, 1)
print(x)
# Out:
# ['The', 'rain in Spain']

# %% [markdown]
# ### The sub() Function

# %% [markdown]
# The <span style='color:red'>sub()</span> function replaces the matches with the text of your choice:

# %%
import re

txt = "The rain in Spain"
x = re.sub(" ", "---", txt)
print(x)
# Out:
# The---rain---in---Spain

# %% [markdown]
# You can control the number of replacements by specifying the <span style='color:red'>count</span> parameter:

# %%
import re

txt = "The rain in Spain"
x = re.sub(" ", "---", txt, 2)
print(x)
# Out:
# The---rain---in Spain

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>MetaCharacters</b></div>
#
# To understand the RE analogy, MetaCharacters are useful, important, and will be used in functions of module re. Below is the list of metacharacters.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <div class="alert alert-block alert-danger"><b>Python Try Except</b> </div>

# %%
# Python code to illustrate working of try()
def divide(x, y):
    try:
        # Floor Division : Gives only Fractional Part as Answer
        result = x // y
        print("Yeah ! Your answer is :", result)
    except ZeroDivisionError:
        print("Sorry ! You are dividing by zero ")

divide(6, 3)
divide(3,0)
# Out:
# Yeah ! Your answer is : 2
# Sorry ! You are dividing by zero

# %% [markdown]
# - The <span style='color:red'>try</span> block lets you test a block of code for errors.
#
# - The <span style='color:red'>except</span> block lets you handle the error.
#
# - The <span style='color:red'>else</span> block lets you execute code when there is no error.
#
# - The <span style='color:red'>finally</span> block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# ### First get info about Errors

# %% [markdown]
# To see all the datatype and built in method, errors in python

# %%
# dir(__builtin__)

# %% [markdown]
# If you want to check only errors, then

# %%
# for i in dir(__builtins__):
#     if "Error" in i:
#         print(i)

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Exception Handling</b></div>
#
# - When an error occurs, or exception as we call it, Python will normally stop and generate an error message.
#
# - These exceptions can be handled using the `except` statement:

# %%
#The try block will generate an error, because m is not defined:

try:
  print(m)          # This line will give an error, bcz m is string and it is not in ''.
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %% [markdown]
# Since the try block raises an error, the except block will be executed.
#
# Without the `except` block, the program will crash and raise an error.

# %% [markdown]
# ### To show Error message

# %% [markdown]
# __Example:__

# %%
try:
    i = input()
    print(5/i)
    print('result printed')
except Exception as e:
    print(f"Error message - {e}")
# Out:
# 12
# Error message - unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# What will python do, it will show the whatever error in the `e`, and then you can print that error.

# %% [markdown]
# __Example:__

# %%
l = [2,0,'hello',None]

for element in l:
    try:
        print('Current Element:', element)
        result = 10/int(element)
        print(result)
    except Exception as e:
        print('Error Message:', e)
    print('--'*20)
# Out:
# Current Element: 2
# 5.0
# ----------------------------------------
# Current Element: 0
# Error Message: division by zero
# ----------------------------------------
# Current Element: hello
# Error Message: invalid literal for int() with base 10: 'hello'
# ----------------------------------------
# Current Element: None
# Error Message: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# ----------------------------------------

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Many Exceptions</b></div>
#
# You can define as many exception blocks as you want, e.g. if you want to execute a special block of code for a special kind of error:

# %% [markdown]
# __Example:__

# %%
try:
  print(m)
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")
# Out:
# Variable x is not defined

# %% [markdown]
# __Example:__

# %%
try:
    value = int(input('Enter a natural number: '))
    print('The reciprocal of', value, 'is', 1/value)        
except ValueError:
    print('I do not know what to do.')    
except ZeroDivisionError:
    print('Division by zero is not allowed in our Universe.')
# Out:
# Enter a natural number: 0
# Division by zero is not allowed in our Universe.

# %% [markdown]
# __Example:__

# %%
l = [2,0,'hello',None]

for element in l:
    try:
        print('Current Element:', element)
        result = 10/int(element)
        print(result)
    except ZeroDivisionError as e:
        print('A zero division error occured.')
    except Exception as e:
        print('Error Message:', e)
    print('--'*20)
# Out:
# Current Element: 2
# 5.0
# ----------------------------------------
# Current Element: 0
# A zero division error occured.
# ----------------------------------------
# Current Element: hello
# Error Message: invalid literal for int() with base 10: 'hello'
# ----------------------------------------
# Current Element: None
# Error Message: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# ----------------------------------------

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Else</b></div>

# %% [markdown]
# You can use the <span style='color:red'>else</span> keyword to define a block of code to be executed if no errors were raised:

# %% [markdown]
# __Example:__

# %%
#The try block does not raise any errors, so the else block is executed:

try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %% [markdown]
# __Example:__

# %%
try:
    value = int(input('Enter a natural number: '))
    print('The reciprocal of', value, 'is', 1/value)        
except ValueError:
    print('I do not know what to do.')    
except ZeroDivisionError:
    print('Division by zero is not allowed in our Universe.')    
else:
    print('Something strange has happened here... Sorry!')
# Out:
# Enter a natural number:
# I do not know what to do.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Finally</b></div>

# %% [markdown]
# The <span style='color:red'>finally</span> block, if specified, will be executed regardless if the try block raises an error or not.

# %%
try:
  print(m)
except:
  print("Something went wrong")
finally:
  print("The 'try except' is finished")
# Out:
# Something went wrong
# The 'try except' is finished

# %% [markdown]
# __Difference between `else` block and `finally` block__: The else block lets you execute code when there is no error. The finally block lets you execute code, regardless of the result of the try- and except blocks.

# %% [markdown]
# __Example:__

# %%
file = open('Sample.txt', 'w')

try:
    file.write('testing')
    print('Writing to a file.')
    
except IOError:
    print('Could not write to file.')
    
else:
    print('Write successful')
    
finally:
    file.close()
    print('File Closed.')
# Out:
# Writing to a file.
# Write successful
# File Closed.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Raise an exception</b></div>

# %% [markdown]
# As a Python developer you can choose to throw an exception if a condition occurs.
#
# To throw (or raise) an exception, use the raise keyword.

# %%
# a = -1

# if a < 0:
#   raise Exception("Sorry, no numbers below zero")

# %% [markdown]
# The <span style='color:red'>raise</span> keyword is used to raise an exception.
#
# You can define what kind of error to raise, and the text to print to the user.

# %%
# x = "hello"
    
# if not type(x) is int:
#   raise TypeError("Only integers are allowed")

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Some useful exceptions</b></div>

# %% [markdown]
# Let’s discuss in more detail some useful (or rather, the most common) exceptions you may experience.
#
# ### ZeroDivisionError
#
# This appears when you try to force Python to perform any operation which provokes division in which the divider is zero, or is indistinguishable from zero. Note that there is more than one Python operator which may cause this exception to raise. Can you guess them all?<br>
#
# Yes, they are: `/`, `//`, and `%`.
#
#
# ### ValueError
#
# Expect this exception when you're dealing with values which may be inappropriately used in some context. In general, this exception is raised when a function (like `int()` or `float()`) receives an argument of a proper type, but its value is unacceptable.

# %% [markdown]
# ### TypeError
#
# This exception shows up when you try to apply a data whose type cannot be accepted in the current context. Look at the example:

# %%
# short_list = [1]
# one_value = short_list[0.5]

# %% [markdown]
# You're not allowed to use a float value as a list index (the same rule applies to tuples, too). `TypeError` is an adequate name to describe the problem, and an adequate exception to raise.

# %% [markdown]
# ### AttributeError
#
# This exception arrives – among other occasions – when you try to activate a method which doesn't exist in an item you're dealing with. For example:

# %%
# short_list = [1]
# short_list.append(2)
# short_list.depend(3)

# %% [markdown]
# The third line of our example attempts to make use of a method which isn’t contained in the lists. This is the place where `AttributeError` is raised.

# %% [markdown]
# ### SyntaxError
#
# This exception is raised when the control reaches a line of code which violates Python's grammar. It may sound strange, but some errors of this kind cannot be identified without first running the code. This kind of behavior is typical of interpreted languages – the interpreter always works in a hurry and has no time to scan the whole source code. It is content with checking the code which is currently being run. An example of such a category of issues will be presented very soon.
#
# It's a bad idea to handle this exception in your programs. You should produce code that is free of syntax errors, instead of masking the faults you’ve caused.

# %% [markdown]
# ## <div class="alert alert-block alert-danger"><b>Python logging</b> </div>

# %% [markdown]
# - In its simplest term, the `logging` module is used to print things out (to the console or to a file).
#
# - The `logging` module should be used to communicate with the developer (e.g. information about what’s happening; when an error happens; a critical problem; etc…).
#
# - To communicate with the user, continue using `print()` and `input()`.
#
# - To use logging, we just have to import the `logging` module and get a new logger:

# %%
import logging

logger = logging.getLogger('test_logger')

logger.info("This won't show up.")
logger.warning('This will.')
# Out:
# WARNING:test_logger:This will.

# %% [markdown]
# There are various logging levels (below in ascending order of criticality), for you to use depending on the circumstance:
#
# - DEBUG
# - INFO
# - WARNING
# - ERROR
# - CRITICAL
#
# By default it will print only after `INFO` level.
#
# So if you’re logging for help while developing or debugging, use the `DEBUG` level (`logger.debug('message')`).
#
# If your program’s about to crash because a critical exception happened; use `logger.critical()`.
#
# You can configure the output so all messages are shown, not just warning and above:
#
# If you want to print DEBUG/INFO you have to set level.

# %%
import logging

logger = logging.getLogger('test_logger')
logging.basicConfig(level = logging.INFO)

logger.info('This will not shown up')
logger.warning('This will shown up')
# Out:
# WARNING:test_logger:This will shown up

# %% [markdown]
# - It will not showing info messege, bcz it is not working in Jupyter notebook. If you try in pycharm it will work.

# %% [markdown]
# You can modify the output messsege also.

# %%
import logging

logger = logging.getLogger('test_logger')
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG)

logger.info('This will not shown up')
logger.warning('This will shown up')
# Out:
# WARNING:test_logger:This will shown up

# %% [markdown]
# Same. bcz of jupyter it is not working

# %% [markdown]
# You’ll then have to decide how you want to log things, and as most things in software that should be a team decision.

# %%
import logging

logging.basicConfig(format='%(asctime)s %(levelname)-8s [%(filename)s:%(lineno)d] %(message)s',
    datefmt='%d-%m-%Y:%H:%M:%S',
    level=logging.DEBUG)

logger = logging.getLogger('my_app')
logger.debug("This is a debug log")
logger.info("This is an info log")
logger.critical("This is critical")
logger.error("An error occurred")
# Out:
# CRITICAL:my_app:This is critical
# ERROR:my_app:An error occurred

# %% [markdown]
# And if you wanted your applications logs to go to a file instead of the console, do something like this:

# %%
import logging

logger = logging.getLogger('test_logger')
logging.basicConfig(format='%(asctime)s %(levelname)-8s [%(filename)s:%(lineno)d] %(message)s',
    datefmt='%d-%m-%Y:%H:%M:%S',
    level=logging.DEBUG,
    filename='logs.txt')

logger.warning('Warning Messege')
logger.error('Error Message ')
# Out:
# WARNING:test_logger:Warning Messege
# ERROR:test_logger:Error Message

# %% [markdown]
# If you call `logging.getLogger('my_app')` from many different files, you’ll always get the same `Logger` object—so any configuration changes and the handler added will be reflected throughout all the app.
#
# If you want to use a different name but want the configuration to be kept between handlers, the best way is to create child handlers

# %% [markdown]
# More you can read from this link: <br>
# https://realpython.com/python-logging/

# %% [markdown]
# ## <div class="alert alert-block alert-danger"><b>Object Oriented Programming</b> </div>

# %% [markdown]
# - In programming languages, mainly there are two approaches that are used to write code or program.
#    - Prodecural Programming
#    - Object-Oriented Programming
# - Procedural programming is a programming paradigm built around the idea that programs are sequences of instructions to be executed. They focus heavily on splitting up programs into named sets of instructions called procedures, analogous to functions
# - In Python, object-oriented Programming (OOPs) is a programming paradigm (a typical example or pattern of something) that uses objects and classes in programming. It aims to implement real-world entities like __inheritance__, __polymorphisms__, __encapsulation__, etc. in the programming. The main concept of OOPs is __to bind the data and the functions that work on that together as a single unit__ so that no other part of the code can access this data.

# %% [markdown]
# There are some features in oops, are given below:
#
# ![image-4.png](attachment:image-4.png)
#
# ###  Class:
# A class is a __blueprint__ or __template__ for creating object. It defines the __properties__ and __methods__ that an object of that class will have. Properties are the __data__ or __state__ of an object and methods are the __actions__ or __behaviors__ of an object can perform.
# ### Object:
# An object is an instance of the class and it contain its own data and methods. For example, you could create a class called `person` that has properties like `name`, `age` and methods such as `talk()` and `walk()`. Each instance of person class would be unique object with its own name and age, but they would have same method to speak and walk.
# ### Encapsulation:
# Encapsulation means that the __internal state of an class is hidden__ and can only be accessed or modified through the object's methods. This helps to __protect the object's data__ and prevent it from being modified in unexpected ways.
# ![image.png](attachment:image.png)
# ### Inheritance:
# Inheritance allows new classes to be created that __inherit the properties and method of an existing class__. This allows for code reuse and makes it easy to create new classes that have similar functionality to existing classes.
# ### Polymorphism:
# Polymorphism means that objects of different classess can be created as they were object of common class. This allows greater flexibility in code and makes it easier to write a code that can work with multiple type of objects.
#
# ![image-2.png](attachment:image-2.png)
#
# As you can see, I've created only one object `speak()` and you can see I'm getting three responses from differnet classes.
#
#
# ### Abstraction
# Abstraction in python is defined as a process of __handling complexity by hiding unnecessary information__ from the user.Abstraction provides a programmer to hide all the irrelevant data/process of an application in order to reduce complexity and increase the efficiency of the program
#
#
#
#
#
#
#
#
# In summary, OOP in Python allows developers to __model real-world concepts__ and __entities__ using classes and objects, encapsulates data, reuse code through inheritance,and write more flexible code through polymorphism.<br>

# %% [markdown]
# Let's understand with practial example, Suppose you're playing a Game `GTA-5`. In that game except our characters there are lots of characters in the city like police, villan, gangstar, normal people etc. Now our task is to create 5 police, how we can create.
# - First we create a variable police_1, police_2, etc.
# - Then we will give speratly power, gun, car to each police with seperate varaibles like given below:
#    - Police_1
#       - gun
#       - power
#       - car
#    - Police_2
#       - gun
#       - power
#       - car
#    - Police_3
#       - gun
#       - power
#       - car<br>
# etc.<br>
# - As you can see we need to create lots of same variable for each police. Now suppose we need to create 100 police ?? In that case Object-Oriented Programing comes into picture.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Main Concepts of Object-Oriented Programming (OOPs) </b></div>
#
# - Class
# - Objects
# - Polymorphism
# - Encapsulation
# - Inheritance
# - Data Abstraction

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Class</b></div>

# %% [markdown]
# - Python is an object oriented programming language.
# - Almost everything in Python is an object, with its properties and methods.
# - A Class is like an object constructor, or a "blueprint" for creating objects.
# - A class is a collection of objects. A class contains the blueprints or the prototype from which the objects are being created. It is a logical entity that contains some attributes and methods.
#
# __Let's understand by example:__
#
# A class is considered as a blueprint of objects. We can think of the class as a sketch (prototype) of a house. It contains all the details about the floors, doors, windows, etc. Based on these descriptions we build the house. House is the object.
# Since many houses can be made from the same description, we can create many objects from a class.
#
# Let's take another example of Car. Suppose we have blueprint of car then we can make thousands of cars with that blueprint with differnet colors/ properties.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Define Python Class

# %% [markdown]
# We use the `class` keyword to create a class in Python. For example,

# %%
class Dog:
    pass

# %% [markdown]
# In the above example, we have created a class named `dog` using the `class` keyword.

# %% [markdown]
# Let's see an example,

# %%
class Bike:
    name = ""
    gear = 0

# %% [markdown]
# Here,
#
# `Bike` - The name of the class.<br>
# `name/gear` - variables inside the class with default values "" and 0 respectively. <br>

# %% [markdown]
# __Note: The variables inside a class are called attributes.__

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Objects</b></div>
#
# An object is called an instance of a class. For example, suppose `Bike` is a class then we can create objects like `bike1`, `bike2`, etc from the class.

# %% [markdown]
# Let's understand with an example<br>
#
# An object is any entity that has __attributes__ and __behaviors__. For example, a parrot is an object. It has
#
# - attributes - name, age, color, etc.
# - behavior - dancing, singing, etc.
#
# Similarly, a class is a blueprint for that object.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# __An object consists of :__
#
# - __State:__ It is represented by the attributes of an object. It also reflects the properties of an object. It is nothing but the variables. In classes we called them as state.
# - __Behavior:__ It is represented by the methods of an object. It also reflects the response of an object to other objects. It is also same as python function. If we wirte function inside the class then we called that method/ Behavior.
# - __Identity:__ It gives a unique name to an object and enables one object to interact with other objects.

# %% [markdown]
# To understand the state, behavior, and identity let us take the example of the class dog (explained above).
#
# The __identity__ can be considered as the name of the dog.<br>
# __State__ or __Attributes__ can be considered as the breed, age, or color of the dog.<br>
# The __behavior__ can be considered as to whether the dog is eating or sleeping.<br>

# %% [markdown]
# Here's the syntax to create an object.

# %% [raw]
# objectName = ClassName()

# %% [markdown]
# __Example:__ Creating an object

# %% [raw]
# obj = Dog()

# %% [markdown]
# __Example:__

# %%
# create class
class Bike:
    name = "Royal Enfield "
    gear = 5

# create objects of class
bullet = Bike()

# %% [markdown]
# Here, `bike1` is the object of the class. Now, we can use this object to access the class attributes(variables).

# %% [markdown]
# ### Create multiple objects of python class

# %%
# create class
class Car:
    name = "Honda "
    gear = 5

# create objects of class
Car1 = Car()
Car22 = Car()

# %% [markdown]
# As you can see, we've created two objects of class `Car`.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Attributes/State</b></div>

# %% [markdown]
# The variables we define inside the class is attributes. It is just variables but inside the class.

# %% [markdown]
# ### Create a attributes inside the class.

# %%
# create class
class Bike:
    name = "Royal Enfield"   # attributes
    gear = 5

# create objects of class
bike1 = Bike()

# %% [markdown]
# As you can see in the above example we have created the two attributes `name` and `gear`.
#
# Now can we see or access these attribuites outside the class ?? and the answer is __yes__.

# %% [markdown]
# ### Access Class Attributes Using Objects

# %% [markdown]
# We use the `.` notation to access the attributes of a class. For example,

# %% [markdown]
# __Example:__ Access the variables outside the class.

# %%
# create class
class Bike:
    name = "Royal Enfield"   # attributes
    gear = 5

# create objects of class
bike1 = Bike()

# access the gear attribute
print(bike1.name)
print(bike1.gear)
# Out:
# Royal Enfield
# 5

# %% [markdown]
# __Example:__ Chnage the value of the attributes outside the class.

# %%
# define a class
class Bike:
    name = ""
    gear = 0

# create object of class
bike1 = Bike()

# access attributes and assign new values
bike1.name = "Mountain Bike"
bike1.gear = 11

print(f"Name: {bike1.name}, Gears: {bike1.gear} ")
# Out:
# Name: Mountain Bike, Gears: 11

# %% [markdown]
# In the above example, we have defined the class named `Bike` with two attributes: `name` and `gear`. Then changed the values of the both attributes and tried to print that.

# %% [markdown]
# __Example 2:__

# %%
class Parrot:
    # class attribute
    name = ""
    age = 0

# create parrot1 object
parrot1 = Parrot()
parrot1.name = "Blu"
parrot1.age = 10

# create another object parrot2
parrot2 = Parrot()
parrot2.name = "Woo"
parrot2.age = 15

# access attributes
print(f"{parrot1.name} is {parrot1.age} years old")
print(f"{parrot2.name} is {parrot2.age} years old")
# Out:
# Blu is 10 years old
# Woo is 15 years old

# %% [markdown]
# Finally, we have accessed and modified the attributes of an object using the `.` notation.

# %% [markdown]
# __Example__
#
# Let's understand with practial example.<br>
# - You need to create railway ticket form app.
# - First you'll create structure/blueprint of that from. Like with different section - Name,adress,railway name, station like.
# - Once you create a blueprint you need to provide that form (class) to people.
# - When anyone fill that form, he/she will provide there info in that blueprint. Means they are creating an object of that blueprint with information.

# %% [markdown]
# __Example:__ Create an new attributes outside the class.

# %%
# create class
class Bike:
    name = "Royal Enfield"   # attributes
    gear = 5

# create objects of class
bike1 = Bike()

# Create an attribute for bike 1 object
bike1.color = 'Red'

# access the gear attribute
print(bike1.name)
print(bike1.gear)
print(bike1.color)
# Out:
# Royal Enfield
# 5
# Red

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Python Methods</b></div>

# %% [markdown]
# We can also define a function inside a Python class. A Python Function defined inside a class is called a __Method__.
#
# Let's see an example,

# %% [markdown]
# __Example:__ Create a method and call that method.

# %%
class Computer:
    
    # Create method
    def config(self):
        print("i5, 16gb, 1TB")

# Create an Object
comp1 = Computer()
comp2 = Computer()

# Calling a method config for comp1

# method 1
Computer.config(comp1)  

# method 2
comp2.config()

# %% [markdown]
# - As you can see,, we can call a method by 2 ways. But we always refer method2.
# - You have to type __self__ keyword in the bracket of method, it refer to the object. and also if you have to use attributes inside the class, then use __self.__ notation. Otherwise it will give you an error.

# %% [markdown]
# __Example :__

# %%
# create a class
class Room:
    # Create attributes
    length = 0.0
    breadth = 0.0
    
    # method to calculate area
    def calculate_area(self):
        print("Area of Room =", self.length * self.breadth)

# create object of Room class
study_room = Room()

# assign values to all the attributes 
study_room.length = 42.5
study_room.breadth = 30.8

# access method inside class
study_room.calculate_area()
# Out:
# Area of Room = 1309.0

# %% [markdown]
# In the above example, we have created a class named `Room` with:
#
# - __Attributes:__ `length` and `breadth`
#
# - __Method:__ `calculate_area()`
#
# Here, we have created an object named `study_room` from the `Room` class. We then used the object to assign values to attributes: `length` and `breadth`.

# %% [markdown]
# __Example :__

# %%
# create a class
class create_car:
    color = ''
    length = 0.0
    
    # method to calculate area
    def manufacture_car(self):
        print(f"Your car is ready with {self.color} color and {self.length} length.")

# create object of Room class
car1 = create_car()

# assign values to all the attributes 
car1.length = 42.5
car1.color = 'Red'

# access method inside class
car1.manufacture_car()
# Out:
# Your car is ready with Red color and 42.5 length.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Python `__init__`</b></div>

# %% [markdown]
# - If you are coming from different background you must know what is constructors but in Python we called that as `__init__()` method.
#
# - Whenever the class is being initiated, a method namely `__init__()` is always executed. An `__init__()` method is used to assign the values to object properties or to perform the other method that is required to complete when the object is created.

# %% [markdown]
# Let's use the init method in code:

# %%
class Computer:
    
    def __init__(self):
        print('It is computer Configuration: ')
   
# Create an Object
comp1 = Computer()
comp2 = Computer()
# Out:
# It is computer Configuration:
# It is computer Configuration:

# %% [markdown]
# If you see we didn't call `__init__` method. It will automatically call __when we create a object__. We don't need to call separately like given below:

# %% [markdown]
# #### How `__init__` method work:
#
# when `__init__` will call. In backend side `self == comp1` will happen. Means, it will look like `def __init__(comp1):`

# %% [markdown]
# __Example:__

# %%
class Computer:
    
    def __init__(self):
        print('It is computer Configuration: ')
    
    def config(self):
        print("i5, 16gb, 1TB")

# Create an Object
comp1 = Computer()
comp2 = Computer()

# Calling a method config for comp1
comp1.config()
comp2.config()
# Out:
# It is computer Configuration:
# It is computer Configuration:
# i5, 16gb, 1TB
# i5, 16gb, 1TB

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Attributes in Detail</b></div>

# %% [markdown]
# As we already know how to create an attributes inside the class. But we can create attributes inside the `__init__` method also. When you created the attributed inside the class without `__init__` method, the python will automatically call `__init__` method and create the attributed inside the `__init__` method only. But it will happen in backend.

# %% [markdown]
# __Example:__

# %%
class Computer:
    
    def __init__(self):
        
        # Create two attributes : name & age
        self.name = 'Mrunal'
        self.age = 24
        print(f"My name is {self.name} and age is {self.age}")
 

# Create an Object
comp1 = Computer()

# access that attributes 
print(comp1.name)
print(comp1.age)
# Out:
# My name is Mrunal and age is 24
# Mrunal
# 24

# %% [markdown]
# ### Modify Attribute Values:
#
# You can change an attributes value in two ways:
# 1) Modifying an Attributes value Directly<br>
# 2) Modifying an Attributes value Through a Method<br>

# %% [markdown]
# #### 1. Modifying an Attributes value Directly:

# %% [markdown]
# __Example:__

# %%
# define a class
class Bike:
    name = ""
    gear = 0

# create object of class
bike1 = Bike()

# access attributes and assign new values
bike1.gear = 11
bike1.name = "Mountain Bike"

print(f"Name: {bike1.name}, Gears: {bike1.gear} ")
# Out:
# Name: Mountain Bike, Gears: 11

# %% [markdown]
# In the above example, we have defined the class named `Bike` with two attributes: `name` and `gear`.
#
# We have also created an object `bike1` of the class `Bike`.

# %% [markdown]
# __Example:__

# %%
class Parrot:

    # class attribute
    name = ""
    age = 0

# create parrot1 object
parrot1 = Parrot()
parrot1.name = "Blu"
parrot1.age = 10

# create another object parrot2
parrot2 = Parrot()
parrot2.name = "Woo"
parrot2.age = 15

# access attributes
print(f"{parrot1.name} is {parrot1.age} years old")
print(f"{parrot2.name} is {parrot2.age} years old")
# Out:
# Blu is 10 years old
# Woo is 15 years old

# %% [markdown]
# __Example:__

# %%
class Computer:
 def __init__(self):
    self.name = 'Navin'
    self.age = 28
 
# Create an object
c1 = Computer()
c2 = Computer()

# Change the value of attributes
c1.name = 'Rashi' 
c2.age = 12

print (c1.name, c1.age)
print (c2.name, c2.age)
# Out:
# Rashi 28
# Navin 12

# %% [markdown]
# __Example:__

# %%
class Computer:
    
    def __init__(self):
        
        # Create two attributes : name & age
        self.name = 'Mrunal'
        self.age = 24
        print(f"My name is {self.name} and age is {self.age}")
 

# Create an Object
comp1 = Computer()      # these line will call __init__ method and print the print() line
comp2 = Computer()

# change the value of attributes for object comp1
comp1.name = 'Rashi'
comp1.age = 34

# access that attributes 
print("comp1 Object: ", comp1.name, comp1.age)
print("comp2 Object: ", comp2.name, comp2.age)
# Out:
# My name is Mrunal and age is 24
# My name is Mrunal and age is 24
# comp1 Object:  Rashi 34
# comp2 Object:  Mrunal 24

# %% [markdown]
# #### 2. Modifying an Attributes value Through a Method

# %% [markdown]
# Now you want to change the attributes value from staring. You can modify that values using method(function).<br>
#
#
# __Example:__

# %%
class Computer:
 def __init__(self):
    self.name = 'Navin'
    self.age = 28
    
 def update (self): # Make an Method for changing value 
    self.age = 30 
 
c1 = Computer()
c2 = Computer()

c1.update() # Calling Method

print (c1.name, c1.age)
print (c2.name, c2.age)
# Out:
# Navin 30
# Navin 28

# %% [markdown]
# __Example:__

# %%
class Computer:
    
    def __init__(self):
        
        # Create two attributes : name & age
        self.name = 'Mrunal'
        self.age = 24
        print(f"My name is {self.name} and age is {self.age}")
    
    def update(self):
        self.age = 52
 

# Create an Object
comp1 = Computer()
comp2 = Computer()

# change the value of attributes for object comp1
comp1.name = 'Rashi'
comp1.age = 34

# Update the age value for comp2 object
comp2.update()

# access that attributes 
print("comp1 Object: ", comp1.name, comp1.age)
print("comp2 Object: ", comp2.name, comp2.age)
# Out:
# My name is Mrunal and age is 24
# My name is Mrunal and age is 24
# comp1 Object:  Rashi 34
# comp2 Object:  Mrunal 52

# %% [markdown]
# #### Setting a Default Value for an Attributes:

# %%
class Person:
 def __init__(self, name, age):
    self.name = name
    self.age = age
    self.sex = 'Male' # Set default Value
    
    
 def myfunc(self): 
    print("Hello my name is " + self.name) 

 def abouts(self): # Make an Method for an default value
    print(f'The sex of person p1 is {self.sex}') 
    
p1 = Person("John", 36) 
p2 = Person('Mrunal', 22) 

p1.abouts() # Calling Methods
p1.myfunc() 
p2.myfunc()
# Out:
# The sex of person p1 is Male
# Hello my name is John
# Hello my name is Mrunal

# %% [markdown]
# ### Types of Variables:
#
# 1) Instance Variable (For Changing values for Specific Object)<br>
# 2) Class (Static) variable (It affect on all the Object)<br>
# 3) Private Variables
# 4) Protected Variables

# %% [markdown]
# ### 1. Instance variables (Public Variables):
#
# Data members are accessible within the class and outside the class without any restrictions.

# %%
class Employee:
    def __init__(self, name, salary, project):
        self.name = name                   # Instance Variable
        self.salary = salary               # Instance Variable
        self.project = project             # Instance Variable
        
    def intro(self):
        print(self.name,self.salary)
        
    def work(self):
        print(self.name,self.project)
        
# Create object
emp1 = Employee('Mrunal', 1000000, 'R&D')
emp1.salary
# Out:
# 1000000

# %% [markdown]
# As you can see, we can access the private things inside the class and outside the class also. And we can change that also by modifying it.

# %%
emp1.salary = 10

# %%
emp1.salary
# Out:
# 10

# %% [markdown]
# This is the example of public variables.

# %% [markdown]
# ### 2. Class Variables
#
# It is same as instance variable, you can access the variables inside the class or outside the class also.

# %%
class Car:
    wheels = 4
    logo = '^'        # Class Variables
    
    def __init__(self):
        self.mil = 10 
        self.com = 'BMW'
        
    def company(self):
        print(self.logo)
        
 
c1 = Car()
c2 = Car()
 
print (c1.com, c1.mil, c1.wheels)
print (c2.com, c2.mil, c1.wheels)

print(c1.company())  # Call the company method

# Change the value of logo
c1.logo = '>'

print(c1.company())
# Out:
# BMW 10 4
# BMW 10 4
# ^
# None
# >
# None

# %% [markdown]
# ### 3. Private Variables

# %% [markdown]
# When you want to make your variable private. So you can use that varible inside the class only.

# %%
class Employee:
    def __init__(self,name,salary,project):
        self.name = name
        self.salary = salary
        self.project = project
        
    def intro(self):
        print(self.name,self.salary)
        
    def work(self):
        print(self.name,self.project)
        
emp1 = Employee('Mrunal','3.6 lpa','Bpost')
emp1.salary
# Out:
# '3.6 lpa'

# %% [markdown]
# In above example I can access the salary, I can see the salary. But I want to keep my salary private that's where __Private Varibles__ comes.

# %%
# class Employee:
#     def __init__(self,name,salary,project):
#         self.name = name
#         self.__salary = salary     # to make variable private, use __ before varible name
#         self.project = project
#     def intro(self):
#         print(self.name,self.salary)
#     def work(self):
#         print(self.name,self.project)
        
# emp1 = Employee('Mrunal','3.6 lpa','Bpost')
# emp1.salary

# %% [markdown]
# As you can see I'm not able to see my salary now.
# To make my variable private I used `__salary` variable. Just give double `__` . But if I use that private varible inside a method and try to print, it will. Let's understand with below example.

# %%
class Employee:
    def __init__(self,name,salary,project):
        self.name = name
        self.__salary = salary     # to make variable private, use __ before varible name
        self.project = project
    def intro(self):
        print(self.name,self.__salary)    # using the private variable inside the method.
    def work(self):
        print(self.name,self.project)
        
emp1 = Employee('Mrunal','3.6 lpa','Bpost')
emp1.intro()
# Out:
# Mrunal 3.6 lpa

# %% [markdown]
# We can't access the private varible directly but through method we can access. Only with the help of method, update/print your private variables. Lets understand by more example

# %% [markdown]
# __Example:__

# %%
class Test:
    def __init__(self):
        self.p = 1
        self.__q = 1 
        
    def get(self):
        return self.__q
    
t = Test()
print(t.get())
# Out:
# 1

# %% [markdown]
# __Example:__ Change the value of the private variable through the method.

# %%
class Test:
    def __init__(self):
        self.p = 1
        self.__q = 1 
        
    def get(self):
        return self.__q
    
    def set(self):
        self.__q = +10
        return self.__q
    
t = Test()
print(t.set())
# Out:
# 10

# %% [markdown]
# Now, what exactly python do with private variables ?
#
# So, python internally change the name of the private variable. Suppose we have craeted the variable `get` inside the `Emp` class then python will convert this variable into `_Emp__get`. That's mean we can access the private variables also outside the class without using the method. Let's understand by the example:

# %% [markdown]
# __Example:__ Access the private variable without using method.

# %%
class Employee:
    def __init__(self,name,salary,project):
        self.name = name
        self.__salary = salary     # to make variable private, use __ before varible name
        self.project = project
        
    def intro(self):
        print(self.name,self.__salary)    # using the private variable inside the method.
        
    def work(self):
        print(self.name,self.project)
        
emp1 = Employee('Mrunal','3.6 lpa','Bpost')

print(emp1._Employee__salary)
# Out:
# 3.6 lpa

# %% [markdown]
# As you can see, we can access the private variables directly also.

# %% [markdown]
# __Example:__ Modify the private variable without using method.

# %%
class Employee:
    def __init__(self,name,salary,project):
        self.name = name
        self.__salary = salary     # to make variable private, use __ before varible name
        self.project = project
        
    def intro(self):
        print(self.name,self.__salary)    # using the private variable inside the method.
        
    def work(self):
        print(self.name,self.project)
        
emp1 = Employee('Mrunal','3.6 lpa','Bpost')

# Modify the private variable
emp1._Employee__salary = '12 lpa'

# Print the private varible
emp1.intro()
# Out:
# Mrunal 12 lpa

# %% [markdown]
# So, try to modify the private varible directly.

# %%
class Employee:
    def __init__(self,name,salary,project):
        self.name = name
        self.__salary = salary     # to make variable private, use __ before varible name
        self.project = project
        
    def intro(self):
        print(self.name,self.__salary)    # using the private variable inside the method.
        
    def work(self):
        print(self.name,self.project)
        
emp1 = Employee('Mrunal','3.6 lpa','Bpost')

# Modify the private variable
emp1.__salary = '12 lpa'

# Print the private varible
emp1.__salary
# Out:
# '12 lpa'

# %% [markdown]
# Why It is not giving any error ??
#
# Bcz when you run `emp1.__salary = '12 lpa'` this line, python will create new variable `__salary` which is not a private. and also for python private varaible `__salary` is `_Emp__salary`, thats why it is not giving name error.

# %% [markdown]
# #### To see all variables inside the class

# %%
emp1.__dict__
# Out:
# {'name': 'Mrunal',
#  '_Employee__salary': '3.6 lpa',
#  'project': 'Bpost',
#  '__salary': '12 lpa'}

# %% [markdown]
# ### 4. Protected Variables
#
# Protected variables we can access within the class and sub-class.

# %% [markdown]
#  ### <div class="alert alert-block alert-success"><b>Arguments</b></div>

# %% [markdown]
# Now let's try by providing some arguments to the object.

# %% [markdown]
# __Example:__

# %%
class Computer:
    
    def __init__(self,cpu,ram):   # 1
        self.CPU = cpu            # 2
        self.RAM = ram            # 3
        print(self.CPU, self.RAM) # 4
        

# Create an Object
comp1 = Computer('i5',16)        # 5
comp2 = Computer('Ryzen', 8)     # 6
# Out:
# i5 16
# Ryzen 8

# %% [markdown]
# We have provided the the two arguments to the class `Computer` for `comp1` & `comp2` objects and you already know whenever we create a variable it will automatically call `__init__` method. That's why we have to give two parameter to the `__init__` method. But that parameter is not belong for `comp1` that why we have to create new variable(attributes) with `self` (Line 2,3).<br>
# So whenever well create new object, it will call `__init__` method automatically.

# %% [markdown]
# #### Now if we want to use CPU & RAM attributes in some another method, how can we ?
#
# If we directly type CPU and RAM in another method, it will through error. To use attrubutes in another method, we have to use `self` with that attributes.

# %%
class Computer:
    
    def __init__(self,cpu,ram):   # 1
        self.CPU = cpu            # 2
        self.RAM = ram            # 3
          
    def config(self):             # 5
        print('Config is ',self.CPU, self.RAM)   # 6

# Create an Object
comp1 = Computer('i5',16)        # 7
comp2 = Computer('Ryzen', 8)     # 8


# Calling a method config for comp1

comp1.config()
comp2.config()
# Out:
# Config is  i5 16
# Config is  Ryzen 8

# %% [markdown]
# Let's take object as a parameter

# %%
class Computer:
    
    def __init__(self):
        self.name = 'Mrunal'
        self.age = 24
    
    def compare(self,other):
        if self.age == other.age:
            return True
        else:
            return False
        
# create object
comp1 = Computer()
comp2 = Computer()

# call an compare method 
if comp1.compare(comp2):
    print('They are Same.')
# Out:
# They are Same.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Types of Methods</b></div>

# %% [markdown]
# 1) Instance Method:<br>
#     1. Accessor Method (For asseccing the value)<br>
#     2. Mutator Methods (For modifying the values)<br>
# 2) Class Method<br>
# 3) Static Method <br>

# %% [markdown]
# ### Instance Method:
#
# The methods that work with Instance variable.

# %% [markdown]
# __Example:__

# %%
class Student:
    
    # Static/class variable
    school = 'JVM'
    
    def __init__(self, m1, m2, m3):
        
        # instance variable
        self.m_1 = m1
        self.m_2 = m2
        self.m_3 = m3
        
    # create an method that will give us average of student
    def avg(self):    # Instance method    
        return (self.m_1 + self.m_2 + self.m_3)/3
        
        
        
# Create an Object
s1 = Student(34,67,94)
s2 = Student(54,77,78)

print("Average of s1 student is ", s1.avg())
# Out:
# Average of s1 student is  65.0

# %% [markdown]
# In the above example the `avg` method is Instance method. But how to know that it is instance method. If you look in the bracket of `avg`, it contain self word means it belongs to object. Because we use self for Object.

# %% [markdown]
# #### 1. Accessor Method

# %% [markdown]
# This method is used to access the state of the object i.e, the data hidden in the object can be accessed from this method. However, this method cannot change the state of the object, it can only access the data hidden. We can name these methods with the word get.

# %%
class Student:
    
    # Static/class variable
    school = 'JVM'
    
    def __init__(self, m1, m2, m3):
        
        # instance variable
        self.m_1 = m1
        self.m_2 = m2
        self.m_3 = m3
        
    # create an method that will give us average of student
    def avg(self):    # Instance method    
        return (self.m_1 + self.m_2 + self.m_3)/3
    
    def get_m(self):  # Accessor method
        return self.m_1
        
        
        
# Create an Object
s1 = Student(34,67,94)
s2 = Student(54,77,78)

print("Student s1 mark for m1 subject is ", s1.get_m())
# Out:
# Student s1 mark for m1 subject is  34

# %% [markdown]
# #### 2.Mutator Methods

# %% [markdown]
# This method is used to mutate/modify the state of an object i.e, it alters the hidden value of the data variable. It can set the value of a variable instantly to a new value. This method is also called as update method. Moreover, we can name these methods with the word set.

# %%
class Student:
    
    # Static/class variable
    school = 'JVM'
    
    def __init__(self, m1, m2, m3):
        
        # instance variable
        self.m_1 = m1
        self.m_2 = m2
        self.m_3 = m3
        
    # create an method that will give us average of student
    def avg(self):    # Instance method    
        return (self.m_1 + self.m_2 + self.m_3)/3
    
    def set_m(self):  # Accessor method
        self.m_1 = 100
        

# Create an Object
s1 = Student(34,67,94)
s2 = Student(54,77,78)

s1.set_m()

print("Updated mark of Student s1 for m1 subject is ",s1.m_1)
# Out:
# Updated mark of Student s1 for m1 subject is  100

# %% [markdown]
# ### Class Method
#
# The methods that work with class/static variable.

# %%
class Student:
    
    # Static/class variable
    school = 'JVM'
    
    def __init__(self, m1, m2, m3):
        
        # instance variable
        self.m_1 = m1
        self.m_2 = m2
        self.m_3 = m3
        
    # create an method that will give us name of the college.
    
    @classmethod              # Decorators
    def clg_name(cls):        # class method
        return cls.school

        
        
        
# Create an Object
s1 = Student(34,67,94)
s2 = Student(54,77,78)

#
print('College name is ', Student.clg_name())
# Out:
# College name is  JVM

# %% [markdown]
# - If you look we used `cls` word in the bracket of `clf_name` method. Because we are using class variable.
# - If you have to create class method. You need to use decorators `@classmethod`

# %% [markdown]
# ### Static Method
#
# If you want to work with method that is not belongs from instance or class method, which is not concern with variables, that time you will be using static method.

# %%
class Student:
    
    # Static/class variable
    school = 'JVM'
    
    def __init__(self, m1, m2, m3):
        
        # instance variable
        self.m_1 = m1
        self.m_2 = m2
        self.m_3 = m3
        
    # create an method that will give us name of the college.
    
    @classmethod              # Decorators
    def clg_name(cls):        # class method
        return cls.school
    
    @staticmethod             # Decorators
    def info():               # Static method
        print('This clg is belongs from jalgaon.')
        
        
# Create an Object
s1 = Student(34,67,94)
s2 = Student(54,77,78)

print(Student.info())
# Out:
# This clg is belongs from jalgaon.
# None

# %% [markdown]
# - The static method doesn't do anything with class variable and static variable.
# - If you look we didn't pass anything in the bracket of `info` because it is not belonging from any class or instance variable.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Decorators</b></div>

# %% [markdown]
# - In Python, a decorator is a design pattern that allows you to modify the functionality of a function by wrapping it in another function. Means a function that takes in a function and returns it by adding some functionality.
# - Python Decorators are powerful and versatile tool that allows you to modify the behavior of functions and methods. They are a way to extend the functionality of a function or method without modifying its source code.<br>
# - A decorator is a function that takes another function as an arguments and return a new function that modifies the behavior of the original funcion. The new function is often referred to as a 'decorated' function. The basic syntax of using decorators is follwoing:

# %% [raw]
# @decorator_function
# def my_function():
#     pass

# %% [markdown]
# The decorator_function notaion is just a shorthand for the following code:

# %% [raw]
# def my_function():
#     pass
#
# my_function = decorator_function(my_function)

# %% [markdown]
# Let's understand with example:

# %% [markdown]
# __Example:__

# %%
def make_pretty(func):
    def inner():
        print("I got decorated")
        func()
    return inner


def ordinary():
    print("I am ordinary")

ordinary()
# Out:
# I am ordinary

# %% [markdown]
# Here, we have created two functions:
#
# - `ordinary()` that prints `"I am ordinary"`
#
# - `make_pretty()` that takes a function as its argument and has a nested function named `inner()`, and returns the inner function.
#
# We are calling the `ordinary()` function normally, so we get the output `"I am ordinary"`. <br>
# Now, let's call it using the decorator function.

# %%
def make_pretty(func):
    # define the inner function 
    def inner():
        # add some additional behavior to decorated function
        print("I got decorated")

        # call original function
        func()
    # return the inner function
    return inner

# define ordinary function
def ordinary():
    print("I am ordinary")
    
# decorate the ordinary function
decorated_func = make_pretty(ordinary)

# call the decorated function
decorated_func()
# Out:
# I got decorated
# I am ordinary

# %% [markdown]
# In the example shown above, `make_pretty()` is a decorator. Notice the code,

# %% [raw]
# decorated_func = make_pretty(ordinary)

# %% [markdown]
# - We are now passing the `ordinary()` function as the argument to the make_pretty().
# - The `make_pretty()` function returns the inner function, and it is now assigned to the `decorated_func` variable.

# %% [raw]
# decorated_func()

# %% [markdown]
# Here, we are actually calling the `inner()` function, where we are printing

# %% [markdown]
# ### @ Symbol With Decorator

# %% [markdown]
# Instead of assigning the function call to a variable, Python provides a much more elegant way to achieve this functionality using the `@` symbol. For example,

# %%
def make_pretty(func):

    def inner():
        print("I got decorated")
        func()
    return inner

@make_pretty
def ordinary():
    print("I am ordinary")

ordinary()
# Out:
# I got decorated
# I am ordinary

# %% [markdown]
# Here, the `ordinary()` function is decorated with the `make_pretty()` decorator using the `@make_pretty` syntax, which is equivalent to calling `ordinary = make_pretty(ordinary)`.

# %% [markdown]
# ### Decorating Functions with Parameters

# %% [markdown]
# The above decorator was simple and it only worked with functions that did not have any parameters. What if we had functions that took in parameters like:

# %% [raw]
# def divide(a, b):
#     return a/b

# %% [markdown]
# This function has two parameters, `a` and `b`. We know it will give an error if we pass in b as 0.<br>
#
# Now let's make a decorator to check for this case that will cause the error.

# %%
def smart_divide(func):
    def inner(a, b):
        print("I am going to divide", a, "and", b)
        if b == 0:
            print("Whoops! cannot divide")
            return

        return func(a, b)
    return inner

@smart_divide
def divide(a, b):
    print(a/b)

divide(2,5)

divide(2,0)
# Out:
# I am going to divide 2 and 5
# 0.4
# I am going to divide 2 and 0
# Whoops! cannot divide

# %% [markdown]
# Here, when we call the `divide()` function with the arguments (2,5), the `inner()` function defined in the `smart_divide()` decorator is called instead.
#
# This `inner()` function calls the original `divide()` function with the arguments 2 and 5 and returns the result, which is 0.4.
#
# Similarly, When we call the `divide()` function with the arguments (2,0), the `inner()` function checks that `b` is equal to 0 and prints an error message before returning `None`.

# %% [markdown]
# ### Chaining Decorators in Python

# %% [markdown]
# Multiple decorators can be chained in Python.
#
# To chain decorators in Python, we can apply multiple decorators to a single function by placing them one after the other, with the most inner decorator being applied first.

# %%
def star(func):
    def inner(*args, **kwargs):
        print("*" * 15)
        func(*args, **kwargs)
        print("*" * 15)
    return inner


def percent(func):
    def inner(*args, **kwargs):
        print("%" * 15)
        func(*args, **kwargs)
        print("%" * 15)
    return inner


@star
@percent
def printer(msg):
    print(msg)

printer("Hello")
# Out:
# ***************
# %%%%%%%%%%%%%%%
# Hello
# %%%%%%%%%%%%%%%
# ***************

# %% [markdown]
# The above syntax of,

# %% [raw]
# @star
# @percent
# def printer(msg):
#     print(msg)

# %% [markdown]
# is equivalent to

# %% [raw]
# def printer(msg):
#     print(msg)
# printer = star(percent(printer))

# %% [markdown]
# The order in which we chain decorators matter. If we had reversed the order as,

# %% [raw]
# @percent
# @star
# def printer(msg):
#     print(msg)

# %% [markdown]
# The output would be:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Inner Class</b></div>

# %% [markdown]
# - A class defined in another class is known as an inner class or nested class. If an object is created using child class means inner class then the object can also be used by parent class or root class. A parent class can have one or more inner classes but generally inner classes are avoided.
#
# - We can make our code even more object-oriented by using an inner class. A single object of the class can hold multiple sub-objects. We can use multiple sub-objects to give a good structure to our program.

# %%
class Student:                                    # Outer class
    
    def __init__(self,name,rollno):               # Constructer method of outer class
        self.name = name
        self.rollno = rollno
        self.lap = self.Laptop()                  # Create an object of inner class inside the outer class
        
    class Laptop():                               # Create an inner class
        
        def __init__(self):                       # Constructer method of inner class
            self.brand = 'HP'
            self.cpu = 'i5'
            self.ram = 8
            
s1 = Student("Kevin",26)                          # Create an object of outer class

print(s1.lap.brand)                               # to fetch value from inner class

lap1 = s1.lap                                     # to create an object for inner class outside the outer class
print(lap1.cpu)
# Out:
# HP
# i5

# %% [markdown]
# ### Why inner class?

# %% [markdown]
# For the grouping of two or more classes. Suppose we have two classes remote and battery. Every remote needs a battery but a battery without a remote won’t be used. So, we make the Battery an inner class to the Remote. It helps us to save code. With the help of the inner class or nested class, we can hide the inner class from the outside world. Hence, Hiding the code is another good feature of the inner class. By using the inner class, we can easily understand the classes because the classes are closely related. We do not need to search for classes in the whole code, they all are almost together. Though inner or nested classes are not used widely in Python it will be a better feature to implement code because it is straightforward to organize when we use inner class or nested class.

# %% [markdown]
# Types of inner classes are as follows:
#
# - Multiple inner class
# - Multilevel inner class

# %% [markdown]
# ### Multiple inner class
#
# - The class contains one or more inner classes known as multiple inner classes. We can have multiple inner class in a class, it is easy to implement multiple inner classes.
#
# __Example: Multiple inner class__

# %%
# create outer class
class Doctors:
    def __init__(self):
        self.name = 'Doctor'
        self.den = self.Dentist()
        self.car = self.Cardiologist()
 
    def show(self):
        print('In outer class')
        print('Name:', self.name)
 
    # create a 1st Inner class
    class Dentist:
        def __init__(self):
            self.name = 'Dr. Savita'
            self.degree = 'BDS'
 
        def display(self):
            print("Name:", self.name)
            print("Degree:", self.degree)
 
    # create a 2nd Inner class
    class Cardiologist:
        def __init__(self):
            self.name = 'Dr. Amit'
            self.degree = 'DM'
 
        def display(self):
            print("Name:", self.name)
            print("Degree:", self.degree)
 
 
# create a object of outer class
outer = Doctors()
outer.show()
 
# create a object of 1st inner class
d1 = outer.den
 
# create a object of 2nd inner class
d2 = outer.car
print()
d1.display()
print()
d2.display()
# Out:
# In outer class
# Name: Doctor
#
# Name: Dr. Savita
# Degree: BDS
#
# Name: Dr. Amit
# Degree: DM

# %% [markdown]
# ### Multilevel inner class
#
# - The class contains an inner class and that inner class again contains another inner class, this hierarchy is known as the multilevel inner class.
#
# __Example: Multilevel inner class__

# %%
# create an outer class
class Geeksforgeeks:
 
    def __init__(self):
        # create an inner class object
        self.inner = self.Inner()
 
    def show(self):
        print('This is an outer class')
 
    # create a 1st inner class
 
    class Inner:
        def __init__(self):
            # create an inner class of inner class object
            self.innerclassofinner = self.Innerclassofinner()
 
        def show(self):
            print('This is the inner class')
 
        # create an inner class of inner
 
        class Innerclassofinner:
            def show(self):
                print('This is an inner class of inner class')
 
 
# create an outer class object
outer = Geeksforgeeks()
outer.show()
print()
 
# create an inner class object
gfg1 = outer.inner
gfg1.show()
print()
 
# create an inner class of inner class object
gfg2 = outer.inner.innerclassofinner
gfg2.show()
# Out:
# This is an outer class
#
# This is the inner class
#
# This is an inner class of inner class

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Python Inheritance</b></div>
#
# The process of inheriting the properties of the parent class to a child class.
#
# - Inheritance allows us to define a class that inherits all the methods and properties from another class.
#
# - __Parent class__ is the class being inherited from, also called base class.
#
# - __Child class__ is the class that inherits from another class, also called derived class.

# %% [markdown]
# ### Create a Parent Class

# %% [markdown]
# __Example:__ Create a class named Person, with firstname and lastname properties, and a printname method:

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

#Use the Person class to create an object, and then execute the printname method:

x = Person("John", "Doe")
x.printname()
# Out:
# John Doe

# %% [markdown]
# ### Create a Child Class
#
# To create a class that inherits the functionality from another class, send the parent class as a parameter when creating the child class:
#
# __Example:__ Create a class named Student, which will inherit the properties and methods from the Person class

# %%
class Student(Person):
    pass

# %% [markdown]
# Now the Student class has the same properties and methods as the Person class.

# %%
x = Student("Mike", "Olsen")
x.printname()
# Out:
# Mike Olsen

# %% [markdown]
# __Example 2:__
#
# Create Parent Class

# %%
class Person():
    
    def __init__(self, name, id):
        self.name = name
        self.id = id
        
    def Display(self):
        print(self.name,self.id)
        
# Create an Object
emp = Person('David',2215558)

emp.Display()
# Out:
# David 2215558

# %% [markdown]
# Create an child class

# %%
class Emp(Person):
    
    def Print(self):
        print('Emp class called')

Emp_details = Emp('Mrunal',278910)

# calling parent class function
print(Emp_details.Display())

# calling child class function
print(Emp_details.Print())
# Out:
# Mrunal 278910
# None
# Emp class called
# None

# %% [markdown]
# ### Different types of Inheritance:
#
# - __Single inheritance:__ When a child class inherits from only one parent class, it is called single inheritance. We saw an example above.
# - __Multiple inheritances:__ When a child class inherits from multiple parent classes, it is called multiple inheritances.
#
# - __Multilevel inheritance:__

# %% [markdown]
# ### Single Inheritance
#
# ![image.png](attachment:image.png)

# %% [markdown]
# __Example:__

# %%
class Vehicle:                                  # Parent Class
    def vehicle_info(self):
        print('Inside the vehicle class.')
        
class Car(Vehicle):                             # child class
    def car_info(self):
        print('Inside the car class.')
        
c1 = Car()                                     # Object of child class

print(c1.vehicle_info())                       # from child class object calling parent class method
# Out:
# Inside the vehicle class.
# None

# %% [markdown]
# ### Multiple Inheritance
#
# Class can inherit features from more than one parent object or parent class.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# __Example:__

# %%
class Person:
    def person_info(self):
        print('Inside the person class.')
class Company:
    def company_info(self):
        print('Inside the company class.')
        
class Employee(Person,Company):
    def employee_info(self):
        print('Inside the employee class.')
        
emp1 = Employee()

print(emp1.person_info())
print(emp1.company_info())
# Out:
# Inside the person class.
# None
# Inside the company class.
# None

# %% [markdown]
# __Example:__

# %%
class Base1(object):
    def __init__(self):
        self.str1 = "Geek1"
        print("Base1")
 
 
class Base2(object):
    def __init__(self):
        self.str2 = "Geek2"
        print("Base2")
 
 
class Derived(Base1, Base2):
    def __init__(self):
 
        # Calling constructors of Base1 and Base2 classes
        Base1.__init__(self)
        Base2.__init__(self)
        print("Derived")
 
    def printStrs(self):
        print(self.str1, self.str2)
 
 
ob = Derived()
ob.printStrs()
# Out:
# Base1
# Base2
# Derived
# Geek1 Geek2

# %% [markdown]
# ### Multilevel inheritance:
#
# Occurs when a class extends a class that extends another class.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# __Example:__

# %%
class Vehicle:                                  # Parent Class
    def vehicle_info(self):
        print('Inside the vehicle class.')
        
class Car(Vehicle):                             # child class
    def car_info(self):
        print('Inside the car class.')
        
class Sport_car(Car):
    def sport_car_info(self):
        print('Inside the sport car.')
        
c1 = Sport_car()                                # Object of child class

c1.vehicle_info()                               # from child class object calling parent class method
# Out:
# Inside the vehicle class.

# %% [markdown]
# __Example:__

# %%
class Base():
 
    # Constructor
    def __init__(self, name):
        self.name = name
 
    # To get name
    def getName(self):
        return self.name
 
 
# Inherited or Sub class (Note Person in bracket)
class Child(Base):
 
    # Constructor
    def __init__(self, name, age):
        Base.__init__(self, name)
        self.age = age
 
    # To get name
    def getAge(self):
        return self.age
 
# Inherited or Sub class (Note Person in bracket)
 
 
class GrandChild(Child):
 
    # Constructor
    def __init__(self, name, age, address):
        Child.__init__(self, name, age)
        self.address = address
 
    # To get address
    def getAddress(self):
        return self.address
 
 
# Driver code
g = GrandChild("Geek1", 23, "Noida")
print(g.getName(), g.getAge(), g.getAddress())
# Out:
# Geek1 23 Noida

# %% [markdown]
# ### Hicrarchical Inhritance:
#
# The type of inheritance that has a hierarchical structure of classes.
#
#
# ![image-2.png](attachment:image-2.png)

# %%
class Vehicle:                                  # Parent Class
    def vehicle_info(self):
        print('Inside the vehicle class.')
        
class Car(Vehicle):                             # child class
    def car_info(self):
        print('Inside the car class.')
        
class Truck(Vehicle):
    def Truck(self):
        print('Inside the truck car.')
        
t1 = Truck()                                # Object of child class
c1 = Car()


t1.vehicle_info()                               # from child class object calling parent class method
c1.vehicle_info()
# Out:
# Inside the vehicle class.
# Inside the vehicle class.

# %% [markdown]
# ### Hybrid Inheritance:
#
# Hybrid inheritance is combination of two or more types of inheritance. It can also be called multi path inheritance.
#
# ![image.png](attachment:image.png)
#
#
#
# Above block diagram shows the hybrid combination of single inheritance and multiple inheritance. Hybrid inheritance is used in a situation where we need to apply more than one inheritance in a program.

# %%
class Vehicle:                                  # Parent Class
    def vehicle_info(self):
        print('Inside the vehicle class.')
        
class Car(Vehicle):                             # child class
    def car_info(self):
        print('Inside the car class.')
        
class Sport_car(Car,Vehicle):
    def Sport_car(self):
        print('Inside the truck car.')
        
                                           
c1 = Sport_car()

c1.vehicle_info()
# Out:
# Inside the vehicle class.

# %% [markdown]
# ### Method Overriding

# %%
class Vehicle:                                  # Parent Class
    def max_speed(self):
        print('Max speed is 100 km/hr')
        
class Car(Vehicle):                             # child class
    def max_speed(self):
        print('Max speed is 200 km/hr')
        
c1 = Car()

c1.max_speed()
# Out:
# Max speed is 200 km/hr

# %% [markdown]
# In this example, `Car` is inherting from `vehicle` class. In both class we have same method. So when we call this method for child class. It first check latest update, means in child class and if it is not there then it goes to the parent class.

# %% [markdown]
# ### Method Resolution Order

# %%
class A:
    def process(self):
        print('in class a')
        
class B(A):
    def process(self):
        print('in class B')
        
class C(B):
    def process(self):
        print('in class C')
        
o1 = C()

o1.process()
# Out:
# in class C

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Use Case- Bank Account System</b></div>
#
# In this case we will use all opps concept and try to understand how we can use opps in real life.

# %% [markdown]
# ### Create class `Account`

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.bal = openingBal

# %% [markdown]
# Default value of balence is 0, it user dosent not give any account balence then default is 0

# %% [markdown]
# ### Create object

# %%
# Create an first object.
a1 = Account(100)

# %%
# Check the account balence of the person(a1)
a1.bal
# Out:
# 100

# %% [markdown]
# As we have given the balence 100, it printed the 100 balence.

# %%
# Check the id of the person(a1)
a1.id
# Out:
# 1

# %% [markdown]
# It is the first customer/person, that's why id it 1 and `counter = 1`

# %%
# Create an second object.
a2 = Account()

# %%
# Check the account balence of the person(a1)
a2.bal
# Out:
# 0

# %% [markdown]
# We are not providing any balence of that person, hence it is showing default value `0`.

# %%
# Check the id of the person(a1)
a2.id
# Out:
# 2

# %% [markdown]
# As this is the second customer, it is showing 2. For first object `a1`, `counter` is 1. Now we are calling `__init__` method again, Hence `counter += 1` will run and `counter = 2`

# %% [markdown]
# ### Create new method

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.bal = openingBal
        
    def __str__(self):
        return f"Account {self.id} has rs{self.bal}"

# %%
# Create an object
a3 = Account(10)
# Out:
# Hello

# %%
print(a3)
# Out:
# Account 1 has rs10

# %% [markdown]
# ### Functionality of the class
#
# - Deposit
# - Withdraw

# %% [markdown]
# #### Create an deposit function

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.bal = openingBal
        self.passbook = []
        
    def deposit(self,amount):            # Created the deposit method
        self.bal += amount
        self.passbook.append(('Creadited', amount))
        
    def __str__(self):
        return f"Account {self.id} has rs{self.bal}"

# %%
# Create two object
a1 = Account(200)
a2 = Account()

# %%
print(a1)
# Out:
# Account 5 has rs200

# %%
# Call the deposit method & add 100 rup into the account
a1.deposit(100)

# %%
# Now Check the account balence
print(a1)
# Out:
# Account 5 has rs300

# %%
a1.passbook
# Out:
# [('Creadited', 100)]

# %% [markdown]
# #### Create an deposit function

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.bal = openingBal
        self.passbook = []
        
    def deposit(self,amount):            # Created the deposit method
        self.bal += amount
        self.passbook.append(('Creadited', amount))
    
    def withraw(self,amount):
        self.bal -= amount
        self.passbook.append(('Debited', amount))
        
    def __str__(self):
        return f"Account {self.id} has rs{self.bal}"

# %%
# Create an objects
a1 = Account(500)
a2 = Account()

# %%
print(a1)
# Out:
# Account 3 has rs500

# %%
# Call the withraw method and withrow 250 rup
a1.withraw(250)

# %%
print(a1)
# Out:
# Account 3 has rs250

# %%
a1.passbook
# Out:
# [('Debited', 250)]

# %% [markdown]
# Now suppose if I did like this

# %%
a1.bal = 123424823

# %%
print(a1)
# Out:
# Account 3 has rs123424823

# %% [markdown]
# This is not we want. So to overcome this problem use private variable.

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.__bal = openingBal
        self.passbook = []
        
    def deposit(self,amount):            # Created the deposit method
        self.__bal += amount
        self.passbook.append(('Creadited', amount))
    
    def withraw(self,amount):
        self.__bal -= amount
        self.passbook.append(('Debited', amount))
        
    def __str__(self):
        return f"Account {self.id} has rs{self.__bal}"

# %% [markdown]
# Change the `bal` to '__bal'

# %%
a1 = Account(1500)
print(a1)
# Out:
# Account 2 has rs1500

# %%
a1.bal = 34544512

# %%
print(a1)
# Out:
# Account 2 has rs1500

# %% [markdown]
# Now you can see our value is not changed.

# %% [markdown]
# But there is one flaw in the code, if you have 0 account balence and still you withraw the amount from the account ?

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.__bal = openingBal
        self.passbook = []
        
    def deposit(self,amount):            # Created the deposit method
        self.__bal += amount
        self.passbook.append(('Creadited', amount))
    
    def withraw(self,amount):
        self.__bal -= amount
        self.passbook.append(('Debited', amount))
        
    def __str__(self):
        return f"Account {self.id} has rs{self.__bal}"

# %%
a1 = Account()
print(a1)
# Out:
# Account 1 has rs0

# %%
# Call the withraw method and withrow 250 rup
a1.withraw(250)
print(a1)
# Out:
# Account 1 has rs-250

# %% [markdown]
# As you can see it is showing -250rup, it should show 0. To avoid this, we used `if` condition.

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.__bal = openingBal
        self.passbook = []
        
    def deposit(self,amount):            # Created the deposit method
        if amount > 0:
            self.__bal += amount
            self.passbook.append(('Creadited', amount))
    
    def withraw(self,amount):
        if self.__bal > amount and amount > 0:            
            self.__bal -= amount
            self.passbook.append(('Debited', amount))
        
    def __str__(self):
        return f"Account {self.id} has rs{self.__bal}"

# %%
# Object 1
a1 = Account()
print(a1)
# Out:
# Account 3 has rs0

# %%
# Call the withraw method and withrow 250 rup
a1.withraw(250)
print(a1)
# Out:
# Account 1 has rs0

# %%
# Object 2
a2 = Account()
print(a2)
# Out:
# Account 2 has rs0

# %%
# Call the withraw method and withrow 250 rup
a2.withraw(-250)     # We have given the negative value
print(a2)
# Out:
# Account 2 has rs0

# %% [markdown]
# ### Inheritance
#
# There is multiple types of account, here we'll consider two account saving account and current account. For this we'll create new classes.

# %%
class SavingsAccount(Account):
    pass

class CurrentAccount(Account):
    pass

# %%
sa1 = SavingsAccount(100)
print(sa1)
# Out:
# Account 4 has rs100

# %% [markdown]
# Bcz `SavingsAccount` class is child class of `Account` class. So it can inherited all the properties and behaviour of the parent class. That's why when you create a object of `SavingsAccount`, it will first check `__init__` method inside the child class and there is no `__init__` method there, it will automatically call parents class method.

# %% [markdown]
# For saving account there is limit for number of trancation. So to set a limit for number of transation for saving account create a variable inside the parent class name as `numTrans` and `maxTrans`.
#
# Second thing we have to do is to change the `deposit` method. In `deposit` method we need to add `numTrans += 1`. So whenever customer deposit the money it will increase number of transcation.
#
# Third thing we have to add is, one more codition in `if` statement.
#
# And all above three logic is same for `withraw` function.

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.__bal = openingBal
        self.passbook = []
        self.numTrans = 0                # Create new Variable to count num of trans
        self.maxTrans = 4
    def deposit(self,amount):                                # Created the deposit method
        if amount > 0 and self.numTrans < self.maxTrans:     # added new condition
            self.__bal += amount
            self.passbook.append(('Creadited', amount))
            self.numTrans += 1
    
    def withraw(self,amount):
        if self.__bal > amount and amount > 0 and self.numTrans < self.maxTrans:    # added new condition        
            self.__bal -= amount
            self.passbook.append(('Debited', amount))
            self.numTrans += 1
        
    def __str__(self):
        return f"Account {self.id} has rs{self.__bal}"
    

class SavingsAccount(Account):
    pass

class CurrentAccount(Account):
    pass

# %%
sal = SavingsAccount(100)
print(sal)
# Out:
# Account 2 has rs100

# %%
sal.deposit(100)
print(sal)
# Out:
# Account 2 has rs200

# %%
sal.deposit(100)

# %%
sal.passbook
# Out:
# [('Creadited', 100), ('Creadited', 100)]

# %%
print(sal)
# Out:
# Account 2 has rs300

# %%
sal.withraw(50)
print(sal)
# Out:
# Account 2 has rs250

# %% [markdown]
# But now there is one problem here, both saving and current account act like same. For that we'll change `CurrentAccount`.

# %%
class CurrentAccount(Account):
    def __init__(self):
        self.maxTrans = 1000

# %%
# a1 = CurrentAccount(100)

# %% [markdown]
# The above line will give you error, bcz the `__init__` method will override the `Account` method `__int__` method. That's why all the varibles we have created in `Account` class, will not accessible by `CurrentAccount` class. That's why it is giving error. To overcome this problem use below:

# %%
class CurrentAccount(Account):
    def __init__(self, openingBal = 0):
        super().__init__(openingBal)     # This line will call the __init__ method from account class
        self.maxTrans = 1000

# %% [markdown]
# So, what we are doing here. First we're overriding the method of `__init__` then in that method we are calling the `__init__` method from `Account` class and execute all the initialize variables from that method. Now let's see our problem is resolved or not.

# %%
class Account:
    # Class Variable
    counter = 0      
    def __init__(self,openingBal = 0): 
        Account.counter += 1 
        self.id = Account.counter        # Instance Variable
        self.__bal = openingBal
        self.passbook = []
        self.numTrans = 0                # Create new Variable to count num of trans
        self.maxTrans = 4
    def deposit(self,amount):                                # Created the deposit method
        if amount > 0 and self.numTrans < self.maxTrans:     # added new condition
            self.__bal += amount
            self.passbook.append(('Creadited', amount))
            self.numTrans += 1
    
    def withraw(self,amount):
        if self.__bal > amount and amount > 0 and self.numTrans < self.maxTrans:    # added new condition        
            self.__bal -= amount
            self.passbook.append(('Debited', amount))
            self.numTrans += 1
        
    def __str__(self):
        return f"Account {self.id} has rs{self.__bal}"
    

class SavingsAccount(Account):
    pass

class CurrentAccount(Account):
    def __init__(self, openingBal = 0):
        super().__init__(openingBal)     
        self.maxTrans = 1000

# %%
cal = CurrentAccount(100)
print(cal)
# Out:
# Account 1 has rs100

# %% [markdown]
# Now I want to apply some coditions:
# - For saving account 5% Discount
# - For current account 1% Discount

# %%
class Account:
  counter = 0
  def __init__(self,openingBal=0):
    Account.counter += 1
    self.id = Account.counter
    self.bal = openingBal
    self.passbook = []
    self.numTrans = 0
    self.maxTrans = 2
  def deposit(self,amount):
    if amount > 0 and self.numTrans < self.maxTrans:
      self.bal += amount
      self.passbook.append(('credited',amount))
      self.numTrans += 1
  def withdraw(self,amount):
    if self.bal > amount and amount > 0 and self.numTrans < self.maxTrans :
      self.bal -= amount
      self.passbook.append(('debited',amount))  
      self.numTrans += 1

  def __str__(self):
    return f"Account {self.id} has rs{self.bal}" 



class SavingsAccount(Account):
  def getInterest(self):
    interest = self.bal * 0.05
    print(interest)


class CurrentAccount(Account):
  def __init__(self,openingBal = 0):
    super().__init__(openingBal)
    self.maxTrans =  1000

  def getInterest(self):
    interest = self.bal * 0.01
    print(interest)

# %%
sal = SavingsAccount(100)
print(sal)
# Out:
# Account 1 has rs100

# %%
sal.getInterest()
# Out:
# 5.0

# %%
cal = CurrentAccount(100)
print(cal)
# Out:
# Account 2 has rs100

# %%
cal.getInterest()
# Out:
# 1.0

# %% [markdown]
# ### Task:
#
# - .
# - Attributes / Data Members

# %% [markdown]
# ## <div class="alert alert-block alert-danger"><b>Python File handling</b> </div>

# %% [markdown]
# - Python too supports file handling and allows users to handle files i.e., to read and write files, along with many other file handling options, to operate on files.
# - The concept of file handling has stretched over various other languages, but the implementation is either complicated or lengthy, but like other concepts of Python, this concept here is also easy and short.
# - Python treats files differently as text or binary and this is important. Each line of code includes a sequence of characters and they form a text file.
# - Each line of a file is terminated with a special character, called the EOL or End of Line characters like comma {,} or newline character. It ends the current line and tells the interpreter a new one has begun.
# - Generally we have two types of files.
#   - Text file: `.txt`, `.csv`, `.xml`
#       - Uses a fix encoding scheme(ASCII, UNICODE)
#
#   - Binary file: `.png`, `.exe`, `.jpeg`, `.pdf`, `.xlsx`
#       - Uses there own encoding scheme.
#       - It is not human readable.
#
# Now, we'll look into only text file. For binary file, there is other libraries.
#
# Let’s start with the reading and writing files.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Working of open() function</b></div>

# %% [markdown]
# Before performing any operation on the file like reading or writing, first, we have to open that file. For this, we should use Python’s inbuilt function `open()` but at the time of opening, we have to specify the mode, which represents the purpose of the opening file.

# %% [raw]
# f = open(filename, mode)

# %% [markdown]
# __Where the following mode is supported:__
#
# - __Read Only__(`r`): Open a text file for reading. The cursor is positioned at the start of the file. Raises a FileNotFoundError if the file does not exist. This is also the default mode used in the open() function.
#
#
# - __Read and Write__(`r+`): Open a text file for reading and writing. The cursor is placed at the start of the file. Raises a FileNotFoundError if the file does not exist.
#
# - __Write Only__(`w`): Open a text for writing. If the file already exists, the contents of the file are deleted first, and a new file is written. Creates a new file if the file does not exist.
#
# - __Write and Read__(`w+`): Open a file for both reading and writing. The cursor is placed at the beginning of the file. Creates a new file if the file does not exist. If the file already exists, the contents of the file are deleted first, and a new file is written.
#
# - __Append only__(`a`): Open a file for writing. The cursor is placed at the end of the file. Creates a new file if the file does not exist. If the file already exists, the contents of the file are not deleted. New text is added to the end of the file.
#
# - __Append and Read__(`a+`): Open the file for reading and writing. The cursor is placed at the end of the file. Creates a new file if the file does not exist. If the file already exists, the contents of the file are not deleted. New text is added to the end of the file.

# %%
# Read a file from a path

file = open(r"C:\Users\wankh\OneDrive\Desktop\Study Material\Excel Sheets\python_file_handling.txt")

# %% [markdown]
# above syntax will open file, now how to show content in that file. If we use direct print statement, it will print like this

# %%
print(file)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\wankh\\OneDrive\\Desktop\\Study Material\\Excel Sheets\\python_file_handling.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Working of close() function</b></div>

# %% [markdown]
# This function doesn't take any argument, and you can directly call the `close()` function using the file object. It can be called multiple times, but if any operation is performed on the closed file, a "ValueError" exception is raised.

# %% [markdown]
# __Syntax:__

# %% [raw]
# file.**close()**

# %% [markdown]
# You can use the 'with' statement with open also, as it provides better exception handling and simplifies it by providing some cleanup tasks. Also, it will automatically close the file, and you don't have to do it manually.
#
# #### Example using with statement

# %%
with open(r"C:\Users\wankh\OneDrive\Desktop\Study Material\Excel Sheets\python_file_handling.txt", mode='r') as f:
   pass

# %% [markdown]
# The method shown in the above section is not entirely safe. If some exception occurs while opening the file, then the code will exit without closing the file. A safer way is to use a try-finally block while opening files.

# %%
try:
    file = open(r"C:\Users\wankh\OneDrive\Desktop\Study Material\Excel Sheets\python_file_handling.txt",mode='r')
    # Perform file handling operations
finally:
    file.close()

# %% [markdown]
# Now, this guarantees that the file will close even if an exception occurs while opening the file. So, you can use the ‘with’ statement method instead. Any of the two methods is good.

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Working of read() mode</b></div>

# %% [markdown]
# There is more than one way to read a file in Python. If you need to extract a string that contains all characters in the file then we can use `file.read()`. The full code would work like this:

# %%
file = open(r"C:\Users\wankh\OneDrive\Desktop\Study Material\Excel Sheets\python_file_handling.txt", 'r')

# %% [markdown]
# To show content in that file, you have to use below syntax

# %%
print(file.read())
# Out:
# Data after write operation Appending new data to the file

# %% [markdown]
# Another way to read a file is to call a certain number of characters like in the following code the interpreter will read the first five characters of stored data and return it as a string:

# %%
print (file.read(10))

# %% [markdown]
# ### <div class="alert alert-block alert-success"><b>Creating a file using write() mode</b></div>

# %%
with open(r"C:\Users\wankh\OneDrive\Desktop\Study Material\Excel Sheets\python_file_handling_1.txt", mode='w') as f:
    f.write("Data after write operation")

# %% [markdown]
# As we have created the new text file name `python_file_handling_1`. And write the above context in that file.

# %%
# Opening file in read mode to check the contents.
with open(r"C:\Users\wankh\OneDrive\Desktop\Study Material\Excel Sheets\python_file_handling_1.txt", mode='r') as f:
    data = f.readlines() 
    print(data)
# Out:
# ['Data after write operation']

# %% [markdown]
# `readlines()`

# %% [markdown]
# # Other TP

# %% [markdown]
# https://www.scaler.com/topics/python/python-keywords-and-identifiers/

# %% [markdown]
# ### Collection Module
#
# https://www.scaler.com/topics/python/python-collection-module/

# %% [markdown]
# #### To see all the datatype and built in method, errors in python

# %%
# dir(__builtin__)

# %% [markdown]
# If you want to check only errors, then

# %%
# for i in dir(__builtins__):
#     if "Error" in i:
#         print(i)
